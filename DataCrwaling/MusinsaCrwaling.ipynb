# %%
import requests
from bs4 import BeautifulSoup as bs
import urllib.request
import urllib.parse

# %%
url = 'https://www.musinsa.com/app/'
values = {'name': 'nesffer',
          'query': 'python'}
headers = {'User-Agent': 'Mozilla/5.0'}
data = urllib.parse.urlencode(values).encode('utf-8')
req = urllib.request.Request(url, data, headers)
f = urllib.request.urlopen(req)
musinsa = bs(f, 'html.parser')
musinsa
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <!-- Google Tag Manager -->
# <script>
# var selfCertEnabled = "" || "Y";
# var THIS_PAGE_GF = 'A'; // 전역필터 상태값 caching page reload 필요 체크용
# var dataLayer = window.dataLayer || [];
# window.addEventListener("DOMContentLoaded", function() {
#
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-TXDSFSF');
# }, false);
# </script>
# <!-- End Google Tag Manager -->
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="/favicon.ico?20200213" rel="shortcut icon" type="image/x-icon"/>
# <meta content="온라인 패션 스토어. 우리가 사랑한 패션의 모든 것, 다 무신사랑 해." name="description">
# <!-- 페이스북 오픈 그래프 메타태그  -->
# <meta content="648837775133366" id="fbAddId" property="fb:app_id">
# <meta content="website" id="fbOgType" property="og:type"/>
# <meta content="무신사 스토어" id="fbOgTitle" property="og:title"/>
# <meta content="https://image.msscdn.net/mfile_s01/fb/share_musinsa.png" id="fbOgImage" property="og:image"/>
# <meta content="온라인 패션 스토어. 우리가 사랑한 패션의 모든 것, 다 무신사랑 해." id="fbOgDescription" property="og:description"/>
# <meta content="https://www.musinsa.com/app/?_gf=A" id="fbOgUrl" property="og:url"/>
# <!--// 페이스북 오픈 그래프 메타태그 -->
# <title>무신사 스토어</title>
# <link href="//static.msscdn.net/static/common/1.2.0/pc.css" rel="stylesheet" type="text/css">
# <link href="//static.msscdn.net/ui/build/pc/css/common.css?202109290900" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/magazine_common.css?202202150915" rel="stylesheet" type="text/css">
# <link href="//static.msscdn.net/skin/musinsa/css/store_common.css?202112011113" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/layout.min.css?202201131000" rel="stylesheet" type="text/css"/>
# <link href="//image.msscdn.net/ui/musinsa/resources/common/css/icon.min.css?202101051200" rel="stylesheet"/>
# <link href="//static.msscdn.net/skin/musinsa/css/guide.min.css?202201281300" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/style.min.css?202201281300" rel="stylesheet" type="text/css"/> <link href="//static.msscdn.net/skin/musinsa/css/sub.css?202202150855" rel="stylesheet" type="text/css"/>
# <link href="//static.msscdn.net/skin/musinsa/css/media_query.css?202010301640" rel="stylesheet" type="text/css"/>
# <!--<link rel="stylesheet" type="text/css" href="//static.msscdn.net/skin/musinsa/css/font.css?20170221" />-->
# <link href="//static.msscdn.net/skin/musinsa/css/new.css?202112010912" rel="stylesheet" type="text/css"/>
# <!-- Swiper -->
# <link href="//static.msscdn.net/swiper/swiper.min.css" rel="stylesheet" type="text/css"/>
# <script src="//static.msscdn.net/swiper/swiper.min.js?20200316"></script>
# <!-- Polyfill -->
# <script>
#     if (/MSIE \d|Trident.*rv:/.test(navigator.userAgent)) {
#         (function (w, d, s) {
#             var f = d.getElementsByTagName(s)[0];
#             var j = d.createElement(s);
#             j.async=true;
#             j.src= '//static.msscdn.net/skin/musinsa/js/polyfill.min.js?features=Array.from,Promise,fetch&flags=always';
#             f.parentNode.insertBefore(j, f);
#         })(window, document, 'script');
#     }
# </script>
# <!-- 스토어, 매거진 공통 스크립트 -->
# <script src="//static.msscdn.net/mfile_outsrc/js/vendor/jquery-1.11.1.min.js?20160201" type="text/javascript"></script>
# <script src="//static.msscdn.net/mfile_outsrc/js/common/base.js?20160201" type="text/javascript"></script>
# <script src="//static.msscdn.net/mfile_outsrc/js/common/common.js?202105041500" type="text/javascript"></script>
# <script src="//static.msscdn.net/mfile_outsrc/js/vendor/jquery.easing.js?20160201" type="text/javascript"></script>
# <!--// 스토어, 매거진 공통 스크립트 -->
# <script src="//static.msscdn.net/skin/musinsa/js/mini_cart.js?202202142135" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/common.js?202202161243" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/jquery.cycle.all.js?20160202" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/m_js/jquery-ui.min.js?20160202" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/jslib.js?20200601" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/jquery.bxslider.js?20180503" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/suggestions.js?202011170900" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/search_form.js?202101121530" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/clipboard.min.js?20170406" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/ui.js?202201261623" type="text/javascript"></script>
# <script src="//static.msscdn.net/static/common/1.2.0/chunk-vendors.js"></script>
# <script src="//static.msscdn.net/skin/js/app/app.js?80be3acf19e8d61c4afd"></script>
# <!--jqModal-->
# <link href="//static.msscdn.net/skin/musinsa/css/jqModal.css?20160119" rel="stylesheet" type="text/css"/>
# <script src="//static.msscdn.net/skin/musinsa/js/jqModal.min.js?20160511" type="text/javascript"></script>
# <!--//jqModal-->
# <!-- 유사 이미지 상품 검색 -->
# <link href="//static.msscdn.net/skin/musinsa/css/image_search.css?202201051301" rel="stylesheet" type="text/css"/>
# <script src="//static.msscdn.net/static/search/js/common/pc/search/image_search.js?20220127" type="text/javascript"></script>
# <script type="text/javascript">
#     var search_front_url = "https://search.musinsa.com";
#
#     $(document).ready(function(){
#         if (window.image_search) {
#             window.image_search.setUrl(search_front_url);
#         }
#     });
#
# </script>
# <!-- //유사 이미지 상품 검색 -->
# <script type="text/javascript">
#     if (!String.prototype.startsWith) {
#         String.prototype.startsWith = function(search, pos) {
#             return this.substr(!pos || pos < 0 ? 0 : +pos, search.length) === search;
#         };
#     }
#
#     var pathname = location.pathname;
#     var validStartsWithUris = [
#         '/app/cart',
#         '/app/order',
#         '/app/goods',
#         '/app/goods/detail',
#         '/app/goods'
#     ];
#
#     if (validStartsWithUris.some(function (uri) {
#         return pathname.startsWith(uri);
#     })) {
#         var sdkInstance = "appInsightsSDK";
#         window[sdkInstance] = "appInsights";
#         var aiName = window[sdkInstance], aisdk = window[aiName] || function (e) {
#             function n(e) {
#                 t[e] = function () {
#                     var n = arguments;
#                     t.queue.push(function () {
#                         t[e].apply(t, n)
#                     })
#                 }
#             }
#
#             var t = {config: e};
#             t.initialize = !0;
#             var i = document, a = window;
#             setTimeout(function () {
#                 var n = i.createElement("script");
#                 n.src = e.url || "https://az416426.vo.msecnd.net/scripts/b/ai.2.min.js", i.getElementsByTagName("script")[0].parentNode.appendChild(n)
#             });
#             try {
#                 t.cookie = i.cookie
#             } catch (e) {
#             }
#             t.queue = [], t.version = 2;
#             for (var r = ["Exception"]; r.length;) n("track" + r.pop());
#             if (n("setAuthenticatedUserContext"), n("clearAuthenticatedUserContext"), n("flush"), t.SeverityLevel = {
#                 Verbose: 0,
#                 Information: 1,
#                 Warning: 2,
#                 Error: 3,
#                 Critical: 4
#             }, !(!0 === e.disableExceptionTracking || e.extensionConfig && e.extensionConfig.ApplicationInsightsAnalytics && !0 === e.extensionConfig.ApplicationInsightsAnalytics.disableExceptionTracking)) {
#                 n("_" + (r = "onerror"));
#                 var o = a[r];
#                 a[r] = function (e, n, i, a, s) {
#                     var c = o && o(e, n, i, a, s);
#                     return !0 !== c && t["_" + r]({message: e, url: n, lineNumber: i, columnNumber: a, error: s}), c
#                 }, e.autoExceptionInstrumented = !0
#             }
#             return t
#         }(
#             {
#                 instrumentationKey: '69ce0c4f-f7d1-4bdc-901b-9aa1c2b1e74a',
#                 disableAjaxTracking: true,
#                 correlationHeaderExcludedDomains: ['*.hotjar.io', '*.hotjar.com', '*.google-analytics.com', '*.googletagmanager.com'],
#                 accountId: '' || getCookie('_ga').split('.').splice(-2).join('.')
#             }
#         );
#         window[aiName] = aisdk;
#
#     }
# </script>
# <script type="text/javascript">
# 	var dataLayer = window.dataLayer || [];
# 	dataLayer.push({
# 		"mainInfo" : {
# 			"email": ""
# 		}
# 	});
# </script>
# <style>
# 	.renew-menu-list > a.active{color:#000 !important; }
# </style>
# <link href="//static.msscdn.net/skin/musinsa/css/main.css?202112221302" rel="stylesheet" type="text/css"/>
# <script src="//static.msscdn.net/skin/musinsa/js/main.js?202202171629" type="text/javascript"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/jquery.lazyload.min.js?20160119" type="text/javascript"></script>
# <script type="text/javascript">
# var storeDomainForSubPage = "https://store.musinsa.com";
# var magazineDomainForSubPage = 'https://www.musinsa.com';
# var ord_amt = "";
# var brand_cnt = "";
# var goods_cnt = "";
#
# $(window).on('load',function(){
# 	blackfridayTopAnimation();
# });
# function blackfridayTopAnimation() {
# 	var $el = $("#bf_ord_amt");
# 	var $el2 = $("#bf_brand_cnt");
# 	var $el3 = $("#bf_goods_cnt");
#
# 	$({ val : 0 }).animate({ val : ord_amt }, {
# 	  duration: 1000,
# 	  step: function() {
# 		$el.text(Comma(Math.floor(this.val)));
# 	  },
# 	  complete: function() {
# 		$el.text(Comma(Math.floor(this.val)));
# 	  }
# 	});
#
# 	$({ val : 0 }).animate({ val : brand_cnt }, {
# 	  duration: 1000,
# 	  step: function() {
# 		$el2.text(Comma(Math.floor(this.val)));
# 	  },
# 	  complete: function() {
# 		$el2.text(Comma(Math.floor(this.val)));
# 	  }
# 	});
#
# 	$({ val : 0 }).animate({ val : goods_cnt }, {
# 	  duration: 1000,
# 	  step: function() {
# 		$el3.text(Comma(Math.floor(this.val)));
# 	  },
# 	  complete: function() {
# 		$el3.text(Comma(Math.floor(this.val)));
# 	  }
# 	});
# }
#
# </script>
# </link></link></meta></meta></head>
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "Organization",
# "name": "musinsa store",
# "url": "https://store.musinsa.com/app/",
# "sameAs": [
# 	"https://www.facebook.com/musinsa",
# 	"https://www.instagram.com/musinsacom/",
# 	"https://twitter.com/musinsacom",
# 	"https://post.naver.com/my.nhn?memberNo=22191262",
# 	"https://www.youtube.com/musinsatv"
# 	]
# }
# </script>
# <body>
# <!-- 팝업 공지사항 -->
# <form name="f1">
# <input name="popup" type="hidden"/>
# <input name="sex" type="hidden" value=""/>
# <input name="u_cat_cd" type="hidden" value=""/>
# </form>
# <!-- 상단 배너 -->
# <!-- 임시 주석 처리
# <div class="top_banner"><img src="//image.msscdn.net/skin/musinsa/images/banner_top.jpg" width="1167" height="50" border="0" alt=""></div>
# --><!-- //상단 배너 -->
# <!-- 상단 콘텐츠 영역 -->
# <script>
# 	var mss = {
# 		ui: {
# 			loggedIn: false,
# 			top: {
# 				extendBannerList: { // 상단 배너 리스트
# 					code: '16MAIN_UP_2_2',
# 					type: 'H',
# 					subject: '16MAIN_UP_2_2_메인_0210쇼케이스_스컬프터',
# 					contents: '<div style="background-color:#D0CDC8"><img src="//image.musinsa.com/images/banner/2022021015153300000020439.jpg" alt="무신사 쇼케이스 스컬프터" class="exImage"></div>',
# 					extendContents: '<div style="background-color:#d0cdc8"><img src="//image.musinsa.com/images/banner/2022021015171000000002204.jpg" alt="무신사 쇼케이스 스컬프터" class="exImage"></div>',
# 					extendUrl: 'https://www.musinsa.com/mz/showcases/view/77420?mode=showcase'
# 				},
# 				campaignList: [ // 캠페인 리스트
#
#
# 							{
# 								hrefTag: {
# 									linkUrl: 'https://www.musinsa.com/app/campaign/index/2022spring',
# 									style: 'color: #ED0060',
# 									text: '봄신상'
# 								}
# 							},
#
#
# 							{
# 								hrefTag: {
# 									linkUrl: 'https://www.musinsa.com/app/campaign/index/kids_grandopen',
# 									style: 'color: #00D47B',
# 									text: '키즈'
# 								}
# 							},
#
#
# 				],
# 			},
# 			left: {
# 				category: {
# 					dCatCd: '', // 선택된 카테고리 코드
# 				},
# 			},
# 		}
# 	};
# </script>
# <div class="top-column column top-musinsa" style="display:none">
# <div class="header header-small store_header clearfix" id="short_top_special">
# <div class="main-wrapper wrapper">
# <h1 class="title"><a href="javascript:void(0)" onclick="showShortTopSpecial(); return false;">MUSINSA STORE 메뉴 열기</a></h1>
# </div>
# </div>
# </div>
# <div id="default_top">
# <div id="topCommonPc"></div>
# </div>
# <script src="//static.msscdn.net/static/common/1.2.0/pc.js"></script><!--// 상단 콘텐츠 영역 -->
# <!-- wrap -->
# <div class="wrap">
# <!-- 왼쪽 메뉴 영역 -->
# <div id="leftCommonPc"></div>
# <script src="//static.msscdn.net/static/common/1.2.0/lnb.js"></script> <!--// 왼쪽 메뉴 영역 -->
# <!-- 오른쪽 콘텐츠 영역 -->
# <div class="right_area main">
# <!--랭킹-->
# <div class="right_container main_ranking_area top-right-container">
# <!-- 랭킹상품 카테고리-->
# <div class="main_category_box" id="ranking_list" style="z-index:20">
# <h2 class="txt_tit_main">랭킹</h2>
# <input id="rank_kind" name="rank_kind" type="hidden" value="goods"/>
# <span class="txt_detail_link"><a href="javascript:void(0)" onclick="All_view('', ''); gtmClickAll('rank_kind'); return false;">전체</a></span>
# <div class="tool-tabBtn renew-menu-list" id="ranking_tab">
# <a class="active" href="javascript:void(0)" onclick="Change_rank_kind('goods');RankingTab('P');gtmClickTab(this, '랭킹'); return false;">상품<span class="new-ranking-date">28분 전</span></a>
# </div>
# <!-- 상품랭킹 랜덤 처리 -->
# <ul class="ranking_category font_basic" id="ranking_goods_pager">
# <li class="activeSlide" u_cat_cd="">
# <a href="javascript:gtmRankingCategory(this)">전체</a>
# </li>
# <li class="" u_cat_cd="001">
# <a href="javascript:gtmRankingCategory(this)">상의</a>
# </li>
# <li class="" u_cat_cd="002">
# <a href="javascript:gtmRankingCategory(this)">아우터</a>
# </li>
# <li class="" u_cat_cd="003">
# <a href="javascript:gtmRankingCategory(this)">바지</a>
# </li>
# <li class="" u_cat_cd="020">
# <a href="javascript:gtmRankingCategory(this)">원피스</a>
# </li>
# <li class="" u_cat_cd="022">
# <a href="javascript:gtmRankingCategory(this)">스커트</a>
# </li>
# <li class="" u_cat_cd="004">
# <a href="javascript:gtmRankingCategory(this)">가방</a>
# </li>
# <li class="" u_cat_cd="018">
# <a href="javascript:gtmRankingCategory(this)">스니커즈</a>
# </li>
# <li class="" u_cat_cd="005">
# <a href="javascript:gtmRankingCategory(this)">신발</a>
# </li>
# <li class="" u_cat_cd="006">
# <a href="javascript:gtmRankingCategory(this)">시계</a>
# </li>
# <li class="" u_cat_cd="007">
# <a href="javascript:gtmRankingCategory(this)">모자</a>
# </li>
# <li class="" u_cat_cd="017">
# <a href="javascript:gtmRankingCategory(this)">스포츠</a>
# </li>
# <li class="" u_cat_cd="008">
# <a href="javascript:gtmRankingCategory(this)">양말/레그웨어</a>
# </li>
# <li class="" u_cat_cd="026">
# <a href="javascript:gtmRankingCategory(this)">속옷</a>
# </li>
# <li class="" u_cat_cd="009">
# <a href="javascript:gtmRankingCategory(this)">안경</a>
# </li>
# <li class="" u_cat_cd="025">
# <a href="javascript:gtmRankingCategory(this)">주얼리</a>
# </li>
# <li class="" u_cat_cd="011">
# <a href="javascript:gtmRankingCategory(this)">액세서리</a>
# </li>
# <li class="" u_cat_cd="015">
# <a href="javascript:gtmRankingCategory(this)">뷰티</a>
# </li>
# <li class="" u_cat_cd="012">
# <a href="javascript:gtmRankingCategory(this)">디지털/테크</a>
# </li>
# <li class="" u_cat_cd="013">
# <a href="javascript:gtmRankingCategory(this)">생활/취미/예술</a>
# </li>
# <li class="" u_cat_cd="014">
# <a href="javascript:gtmRankingCategory(this)">책/음악/티켓</a>
# </li>
# <li class="" u_cat_cd="021">
# <a href="javascript:gtmRankingCategory(this)">반려동물</a>
# </li>
# <li class="" u_cat_cd="055">
# <a href="javascript:gtmRankingCategory(this)">골프용품</a>
# </li>
# <li class="" style="color: red;" u_cat_cd="sale">
# <a href="javascript:gtmRankingCategory(this)">세일</a>
# </li>
# <li class="category_ranking_last" style="color:#f90;" u_cat_cd="new_product">
# <a href="javascript:gtmRankingCategory(this)">신상품</a>
# </li>
# </ul>
# <div class="tool-tabBtn renew-menu-list" id="ranking_tab">
# <a href="javascript:void(0)" onclick="Change_rank_kind('brand');RankingTab('B');gtmClickTab(this, '랭킹');return false;">브랜드 <span class="new-ranking-date">00:40 갱신</span></a>
# </div>
# <!--
# 				<ul class="ranking_category font_basic hidden" id="ranking_brand_pager">
# 					<li class="activeSlide category_ranking_last"><a href="javascript:void(0)">전체</a></li>
# 				</ul>
#
# 				<p class="ranking_date"> 갱신</p>
# 				-->
# </div>
# <!--//랭킹상품 카테고리-->
# <div id="ranking_goods" style="height: 600px; overflow: hidden;">
# <!-- 전체 랭킹 -->
# <div class="main_ranking_item main_contents_maxwidth" style="display:none">
# <ul class="main_contents_size">
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										1위
# 																																	<span class="rank up"><i>▲</i>4</span>
# </p>
# <span class="icon-box-musinsa icon-reverse main-top-reverse">무신사 단독</span>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/640839?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="멜란지 마스터(MELANGE MASTER) 스탠다드 후드 스웨트 집업 - 멜란지 그레이" src="//image.msscdn.net/images/goods_img/20170922/640839/640839_6_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">멜란지 마스터</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/640839?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												스탠다드 후드 스웨트 집업 -...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_price">39,900원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										2위
# 																																	<span class="rank up"><i>▲</i>1</span>
# </p>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/1789507?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="하 아카이브(HAHARCHIVE) 아크 블랙 메신저백" src="//image.msscdn.net/images/goods_img/20210209/1789507/1789507_1_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">하 아카이브</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/1789507?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												아크 블랙...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">79,000원</span>
# <span class="txt_price">75,050원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										3위
# 																																	<span class="rank down"><i>▼</i>2</span>
# </p>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/1034480?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="노스페이스(THE NORTH FACE) NM2DM51A_빅샷" src="//image.msscdn.net/images/goods_img/20190503/1034480/1034480_5_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">노스페이스</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/1034480?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												NM2DM51A_빅샷
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">140,000원</span>
# <span class="txt_price">126,000원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										4위
# 																																	<span class="rank down"><i>▼</i>2</span>
# </p>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/1551840?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="제로(XERO) Deep One Tuck Sweat Pants [Grey]" src="//image.msscdn.net/images/goods_img/20200818/1551840/1551840_1_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">제로</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/1551840?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												Deep One Tuck...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_price">39,000원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										5위
# 																																	<span class="rank up"><i>▲</i>1</span>
# </p>
# <span class="icon-box-musinsa icon-reverse main-top-reverse">무신사 단독</span>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/1558197?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="무신사 스탠다드(MUSINSA STANDARD) 릴렉스드 베이식 블레이저 [블랙]" src="//image.msscdn.net/images/goods_img/20200820/1558197/1558197_3_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">무신사 스탠다드</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/1558197?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												릴렉스드 베이식 블레이저...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">71,900원</span>
# <span class="txt_price">64,690원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										6위
# 																																	<span class="rank down"><i>▼</i>2</span>
# </p>
# <span class="icon-box-limited icon-reverse main-top-reverse">한정 판매</span>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/2339197?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="플랙(PLAC) 런업 X 플랙 스티즈 K33  라이트 블루" src="//image.msscdn.net/images/goods_img/20220203/2339197/2339197_3_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">플랙</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/2339197?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												런업 X 플랙 스티즈 K33...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">149,000원</span>
# <span class="txt_price">119,200원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										7위
# 																																	<span class="rank up"><i>▲</i>2</span>
# </p>
# <span class="icon-box-limited icon-reverse main-top-reverse">한정 판매</span>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/577636?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="아디다스(ADIDAS) BW 아미 - 화이트 / BZ0579" src="//image.msscdn.net/images/goods_img/20170615/577636/577636_4_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">아디다스</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/577636?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												BW 아미 - 화이트 /...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">139,000원</span>
# <span class="txt_price">119,900원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										8위
# 																																	<span class="rank down"><i>▼</i>1</span>
# </p>
# <span class="icon-box-limited icon-reverse main-top-reverse">한정 판매</span>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/1778404?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="토피(TOFFEE) 2WAY 스웻 후드 집업 (MELANGE GREY)" src="//image.msscdn.net/images/goods_img/20210204/1778404/1778404_1_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">토피</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/1778404?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												2WAY 스웻 후드 집업...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">45,000원</span>
# <span class="txt_price">39,000원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										9위
# 																																	<span class="rank up"><i>▲</i>3</span>
# </p>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/2139011?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="레이디 볼륨(LADY VOLUME) 465-1 비건 레더 오버핏 자켓" src="//image.msscdn.net/images/goods_img/20210917/2139011/2139011_3_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">레이디 볼륨</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/2139011?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												465-1 비건 레더 오버핏...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">89,900원</span>
# <span class="txt_price">53,940원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										10위
# 																																	<span class="rank up"><i>▲</i>11</span>
# </p>
# <span class="icon-box-limited icon-reverse main-top-reverse">한정 판매</span>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/2297046?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="플랙(PLAC) 칸디아니 자켓 051Z 로우" src="//image.msscdn.net/images/goods_img/20220107/2297046/2297046_3_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">플랙</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/2297046?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												칸디아니 자켓 051Z...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">179,000원</span>
# <span class="txt_price">161,100원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										11위
# 																																	<span class="rank down"><i>▼</i>3</span>
# </p>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/750908?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="후러브스아트(WHOLOVESART) 유니섹스 세미 와이드 밴딩 슬랙스" src="//image.msscdn.net/images/goods_img/20180406/750908/750908_6_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">후러브스아트</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/750908?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												유니섹스 세미 와이드 밴딩...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">54,000원</span>
# <span class="txt_price">29,900원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										12위
# 																																	<span class="rank down"><i>▼</i>2</span>
# </p>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/1628385?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="예일(YALE) (22ALL) 2 TONE ARCH HOODIE GRAY" src="//image.msscdn.net/images/goods_img/20200928/1628385/1628385_5_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">예일</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/1628385?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												(22ALL) 2 TONE...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">79,000원</span>
# <span class="txt_price">39,500원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										13위
# 																																	<span class="rank up"><i>▲</i>2</span>
# </p>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/1291017?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="제멋(JEMUT) 리치 오버 MA-1 자켓 블랙 YHJK2269" src="//image.msscdn.net/images/goods_img/20200205/1291017/1291017_1_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">제멋</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/1291017?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												리치 오버 MA-1 자켓 블랙...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_price">59,800원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										14위
# 																																	<span class="rank up"><i>▲</i>4</span>
# </p>
# <span class="icon-box-limited icon-reverse main-top-reverse">한정 판매</span>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/2233180?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="반스(VANS) 컴피쿠시 원 - (체커보드) 블랙:마시멜로우" src="//image.msscdn.net/images/goods_img/20211115/2233180/2233180_1_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">반스</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/2233180?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												컴피쿠시 원 - (체커보드)...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_price">109,000원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										15위
# 																																	<span class="rank up"><i>▲</i>7</span>
# </p>
# <span class="mu-icon mu-icon-coupon main_top_coupon"></span>
# <span class="icon-box-limited icon-reverse main-top-reverse">한정 판매</span>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/1139192?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="엘무드(LMOOD) 화란 세미오버 가디건 블랙" src="//image.msscdn.net/images/goods_img/20190902/1139192/1139192_6_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">엘무드</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/1139192?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												화란 세미오버 가디건...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">94,900원</span>
# <span class="txt_price">76,400원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										16위
# 																																	<span class="rank up"><i>▲</i>13</span>
# </p>
# <span class="icon-box-musinsa icon-reverse main-top-reverse">무신사 단독</span>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/1149328?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="무신사 스탠다드(MUSINSA STANDARD) 테이퍼드 히든 밴딩 크롭 슬랙스 [블랙]" src="//image.msscdn.net/images/goods_img/20190910/1149328/1149328_10_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">무신사 스탠다드</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/1149328?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												테이퍼드 히든 밴딩 크롭 슬랙스...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">32,900원</span>
# <span class="txt_price">29,590원</span>
# </p>
# </div>
# </li>
# </ul>
# </div>
# <div class="main_ranking_item main_contents_maxwidth" style="display:none">
# <ul class="main_contents_size">
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										1위
# 																			</p>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/1628385?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="예일(YALE) (22ALL) 2 TONE ARCH HOODIE GRAY" src="//image.msscdn.net/images/goods_img/20200928/1628385/1628385_5_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">예일</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/1628385?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												(22ALL) 2 TONE...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">79,000원</span>
# <span class="txt_price">39,500원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										2위
# 																			</p>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/2369239?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="아웃스탠딩(OUTSTANDING) TWO TONE HOOD SWEAT_NAVY" src="//image.msscdn.net/images/goods_img/20220217/2369239/2369239_1_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">아웃스탠딩</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/2369239?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												TWO TONE HOOD...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">83,000원</span>
# <span class="txt_price">74,700원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										3위
# 																			</p>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/2354305?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="마르디 메크르디(MARDI MERCREDI) SWEATSHIRT UNIV_OATMEAL BLACK" src="//image.msscdn.net/images/goods_img/20220211/2354305/2354305_1_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">마르디 메크르디</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/2354305?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												SWEATSHIRT...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">75,000원</span>
# <span class="txt_price">67,500원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										4위
# 																			</p>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/2286964?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="아노블리어(ANOBLIR) 오버핏 크롭 카라 가디건 [블랙]" src="//image.msscdn.net/images/goods_img/20211230/2286964/2286964_1_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">아노블리어</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/2286964?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												오버핏 크롭 카라 가디건...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">110,500원</span>
# <span class="txt_price">77,300원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										5위
# 																			</p>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/2354252?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="마르디 메크르디(MARDI MERCREDI) SWEATSHIRT FLOWERMARDI_WHITE VIVIDBLUE" src="//image.msscdn.net/images/goods_img/20220211/2354252/2354252_1_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">마르디 메크르디</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/2354252?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												SWEATSHIRT...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">75,000원</span>
# <span class="txt_price">67,500원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										6위
# 																			</p>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/1549281?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="마르디 메크르디(MARDI MERCREDI) SWEATSHIRT FLOWERMARDI_OATMEAL BLACK" src="//image.msscdn.net/images/goods_img/20200814/1549281/1549281_1_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">마르디 메크르디</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/1549281?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												SWEATSHIRT...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">75,000원</span>
# <span class="txt_price">67,500원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										7위
# 																			</p>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/1599217?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="테이크이지(TAKEASY) 램스울 크루넥 오버니트(연차콜)" src="//image.msscdn.net/images/goods_img/20200912/1599217/1599217_1_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">테이크이지</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/1599217?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												램스울 크루넥...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">54,000원</span>
# <span class="txt_price">37,800원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										8위
# 																			</p>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/2204747?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="마르디 메크르디(MARDI MERCREDI) SWEATSHIRT FLOWERMARDI_OATMEAL GREEN" src="//image.msscdn.net/images/goods_img/20211028/2204747/2204747_1_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">마르디 메크르디</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/2204747?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												SWEATSHIRT...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">75,000원</span>
# <span class="txt_price">67,500원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										9위
# 																			</p>
# <span class="icon-box-limited icon-reverse main-top-reverse">한정 판매</span>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/2058188?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="브라운브레스(BROWNBREATH) TAG KEEP HOODIE - BLACK" src="//image.msscdn.net/images/goods_img/20210811/2058188/2058188_10_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">브라운브레스</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/2058188?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												TAG KEEP HOODIE -...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">79,000원</span>
# <span class="txt_price">69,000원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										10위
# 																			</p>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/2339230?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="클렛(CLET) 오픈 카라 롱 슬리브 블라우스 (크림)" src="//image.msscdn.net/images/goods_img/20220203/2339230/2339230_1_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">클렛</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/2339230?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												오픈 카라 롱 슬리브 블라우스...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">84,000원</span>
# <span class="txt_price">71,400원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										11위
# 																			</p>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/1815503?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="지오다노(GIORDANO) 021541 레이어드 반팔 티셔츠(2pck)" src="//image.msscdn.net/images/goods_img/20210225/1815503/1815503_3_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">지오다노</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/1815503?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												021541 레이어드 반팔...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_price">19,800원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										12위
# 																			</p>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/2082210?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="그리쉬(GRISH) 시그니쳐 로고 후드 그레이" src="//image.msscdn.net/images/goods_img/20210824/2082210/2082210_3_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">그리쉬</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/2082210?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												시그니쳐 로고 후드...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">79,000원</span>
# <span class="txt_price">55,000원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										13위
# 																			</p>
# <span class="icon-box-limited icon-reverse main-top-reverse">한정 판매</span>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/2043036?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="코드그라피(CODEGRAPHY) [송필드 PICK][SET] 헤비웨이트 CGP 아치 로고 트레이닝 셋업_멜란지그레이" src="//image.msscdn.net/images/goods_img/20210728/2043036/2043036_3_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">코드그라피</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/2043036?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												[송필드 PICK][SET]...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">97,900원</span>
# <span class="txt_price">69,900원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										14위
# 																			</p>
# <span class="icon-box-limited icon-reverse main-top-reverse">한정 판매</span>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/2226766?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="드로우핏(DRAW FIT) 오버사이즈 집업 카라 터틀넥 니트 [BLACK]" src="//image.msscdn.net/images/goods_img/20211111/2226766/2226766_2_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">드로우핏</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/2226766?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												오버사이즈 집업 카라 터틀넥...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">76,000원</span>
# <span class="txt_price">68,400원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										15위
# 																			</p>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/1191407?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="테이크이지(TAKEASY) 램스울 크루넥 오버니트(블랙)" src="//image.msscdn.net/images/goods_img/20191017/1191407/1191407_2_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">테이크이지</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/1191407?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												램스울 크루넥...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">54,000원</span>
# <span class="txt_price">37,800원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										16위
# 																			</p>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/2064581?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="마르디 메크르디(MARDI MERCREDI) SWEATSHIRT UNIV_NAVY IVORY" src="//image.msscdn.net/images/goods_img/20210813/2064581/2064581_1_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">마르디 메크르디</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/2064581?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												SWEATSHIRT...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">75,000원</span>
# <span class="txt_price">67,500원</span>
# </p>
# </div>
# </li>
# </ul>
# </div>
# <div class="main_ranking_item main_contents_maxwidth" style="display:none">
# <ul class="main_contents_size">
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										1위
# 																			</p>
# <span class="icon-box-musinsa icon-reverse main-top-reverse">무신사 단독</span>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/640839?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="멜란지 마스터(MELANGE MASTER) 스탠다드 후드 스웨트 집업 - 멜란지 그레이" src="//image.msscdn.net/images/goods_img/20170922/640839/640839_6_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">멜란지 마스터</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/640839?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												스탠다드 후드 스웨트 집업 -...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_price">39,900원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										2위
# 																			</p>
# <span class="icon-box-musinsa icon-reverse main-top-reverse">무신사 단독</span>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/1558197?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="무신사 스탠다드(MUSINSA STANDARD) 릴렉스드 베이식 블레이저 [블랙]" src="//image.msscdn.net/images/goods_img/20200820/1558197/1558197_3_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">무신사 스탠다드</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/1558197?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												릴렉스드 베이식 블레이저...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">71,900원</span>
# <span class="txt_price">64,690원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										3위
# 																			</p>
# <span class="icon-box-limited icon-reverse main-top-reverse">한정 판매</span>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/1778404?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="토피(TOFFEE) 2WAY 스웻 후드 집업 (MELANGE GREY)" src="//image.msscdn.net/images/goods_img/20210204/1778404/1778404_1_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">토피</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/1778404?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												2WAY 스웻 후드 집업...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">45,000원</span>
# <span class="txt_price">39,000원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										4위
# 																			</p>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/2139011?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="레이디 볼륨(LADY VOLUME) 465-1 비건 레더 오버핏 자켓" src="//image.msscdn.net/images/goods_img/20210917/2139011/2139011_3_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">레이디 볼륨</p>
# <p>
# <a href="https://store.musinsa.com/app/goods/2139011?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# 												465-1 비건 레더 오버핏...
# 											</a>
# </p>
# <p class="box_price">
# <span class="txt_origin_price">89,900원</span>
# <span class="txt_price">53,940원</span>
# </p>
# </div>
# </li>
# <li class="ranking_item hover_box">
# <p class="n-label label-default txt_num_rank">
# 										5위
# 																			</p>
# <span class="icon-box-limited icon-reverse main-top-reverse">한정 판매</span>
# <div class="ranking_item_img">
# <a href="https://store.musinsa.com/app/goods/2297046?loc=goods_rank" onclick="gtmClickList('랭킹', '상품');">
# <img alt="플랙(PLAC) 칸디아니 자켓 051Z 로우" src="//image.msscdn.net/images/goods_img/20220107/2297046/2297046_3_320.jpg"/><span class="vertical_standard"></span>
# </a>
# </div>
# <div class="ranking_item_intro">
# <p class="txt_tit_brand">플랙</p>
# <p>
# ...
# <span class="vertical_standard"></span>
# </img></a>
# </li>
# <li class="fl main_brand_logo brandLogo">
# <a href="https://www.musinsa.com/brands/thenorthface" onclick="gtmClickList('주요 브랜드', '');">
# <img alt="THE NORTH FACE/노스페이스" class="lazyload" data-original="//image.msscdn.net/mfile_s01/_brand/free_medium/thenorthface.png?202202151558" src="//image.msscdn.net/0.gif">
# <span class="vertical_standard"></span>
# </img></a>
# </li>
# <li class="fl main_brand_logo brandLogo">
# <a href="https://www.musinsa.com/brands/brownbreath" onclick="gtmClickList('주요 브랜드', '');">
# <img alt="BROWNBREATH/브라운브레스" class="lazyload" data-original="//image.msscdn.net/mfile_s01/_brand/free_medium/brownbreath.png?202202211045" src="//image.msscdn.net/0.gif">
# <span class="vertical_standard"></span>
# </img></a>
# </li>
# <li class="fl main_brand_logo brandLogo">
# <a href="https://www.musinsa.com/brands/lee" onclick="gtmClickList('주요 브랜드', '');">
# <img alt="LEE/리" class="lazyload" data-original="//image.msscdn.net/mfile_s01/_brand/free_medium/lee.png?202201241020" src="//image.msscdn.net/0.gif">
# <span class="vertical_standard"></span>
# </img></a>
# </li>
# <li class="fl main_brand_logo brandLogo">
# <a href="https://www.musinsa.com/brands/covernat" onclick="gtmClickList('주요 브랜드', '');">
# <img alt="COVERNAT/커버낫" class="lazyload" data-original="//image.msscdn.net/mfile_s01/_brand/free_medium/covernat.png?202202211632" src="//image.msscdn.net/0.gif">
# <span class="vertical_standard"></span>
# </img></a>
# </li>
# <li class="fl main_brand_logo brandLogo">
# <a href="https://www.musinsa.com/brands/takeasy" onclick="gtmClickList('주요 브랜드', '');">
# <img alt="TAKEASY/테이크이지" class="lazyload" data-original="//image.msscdn.net/mfile_s01/_brand/free_medium/takeasy.png?202112131653" src="//image.msscdn.net/0.gif">
# <span class="vertical_standard"></span>
# </img></a>
# </li>
# <li class="fl main_brand_logo brandLogo">
# <a href="https://www.musinsa.com/brands/beslow" onclick="gtmClickList('주요 브랜드', '');">
# <img alt="BESLOW/비슬로우" class="lazyload" data-original="//image.msscdn.net/mfile_s01/_brand/free_medium/beslow.png?202202141053" src="//image.msscdn.net/0.gif">
# <span class="vertical_standard"></span>
# </img></a>
# </li>
# <li class="fl main_brand_logo brandLogo">
# <a href="https://www.musinsa.com/brands/lafudgestore" onclick="gtmClickList('주요 브랜드', '');">
# <img alt="LAFUDGESTORE/라퍼지스토어" class="lazyload" data-original="//image.msscdn.net/mfile_s01/_brand/free_medium/lafudgestore.png?202201191540" src="//image.msscdn.net/0.gif">
# <span class="vertical_standard"></span>
# </img></a>
# </li>
# <li class="fl main_brand_logo brandLogo">
# <a href="https://www.musinsa.com/brands/modnine" onclick="gtmClickList('주요 브랜드', '');">
# <img alt="MODNINE/모드나인" class="lazyload" data-original="//image.msscdn.net/mfile_s01/_brand/free_medium/modnine.png?202111111453" src="//image.msscdn.net/0.gif">
# <span class="vertical_standard"></span>
# </img></a>
# </li>
# <li class="fl main_brand_logo brandLogo">
# <a href="https://www.musinsa.com/brands/spao" onclick="gtmClickList('주요 브랜드', '');">
# <img alt="SPAO/스파오" class="lazyload" data-original="//image.msscdn.net/mfile_s01/_brand/free_medium/spao.png?202202161032" src="//image.msscdn.net/0.gif">
# <span class="vertical_standard"></span>
# </img></a>
# </li>
# </ul>
# <!--//주요브랜드 리스트-->
# </div>
# <!--//주요 브랜드-->
# <!-- 큐레이팅 숍 목록 -->
# <div class="n-list-curating">
# <div class="curating-area area1">
# <div>
# <img alt="" class="img lazyload" data-original="//image.msscdn.net/data/curating/23672/23672_1_360.jpg" src="//image.msscdn.net/0.gif"/>
# <div class="cont">
# <div class="txt">
# <strong>봄이 오면 셔츠를 입겠어요</strong>
# <p>다가올 봄날을 맞아 다이아몬드 레이라가 모두가 즐길 수 있는 유니섹스 신상 셔츠를 선보인다. 쾌적하고 관리가 간편한 폴리에스터 소재로 제작되었고, 베이식한 컬러부터 화사한 포인트 컬러까지 다양하다는 것이 장점! 믿고 입는 다이아몬드 레이라 셔츠답게 편안한 실루엣과 탄탄한 디테일로 마무리했다. / 에디터 : 이해인</p>
# </div>
# <a href="https://store.musinsa.com/app/curating/views/23672" onclick="gtmClickList('큐레이팅', '');">상세보기</a>
# </div>
# </div>
# <div>
# <img alt="" class="img lazyload" data-original="//image.msscdn.net/data/curating/23671/23671_1_360.jpg" src="//image.msscdn.net/0.gif"/>
# <div class="cont">
# <div class="txt">
# <strong>세련된 데님 셋업</strong>
# <p>유튜버 런업과 플랙이 만났다! 모던한 컬러와 간결한 디테일로 조용하지만 압도적인 존재감을 뽐내는 녀석. 셋업으로 착용할 수 있는 아이템인데, 일반적인 데님 재킷보다 기장이 짧아 무척 유니크한 덕분에 스타일리시한 룩을 완성할 수 있다. 톡톡한 코튼 100% 소재로 늘어지거나 할 걱정 없이 오래오래 즐기자! / 에디터 : 이해인</p>
# </div>
# <a href="https://store.musinsa.com/app/curating/views/23671" onclick="gtmClickList('큐레이팅', '');">상세보기</a>
# </div>
# </div>
# <div>
# <img alt="" class="img lazyload" data-original="//image.msscdn.net/data/curating/23670/23670_1_360.jpg" src="//image.msscdn.net/0.gif"/>
# <div class="cont">
# <div class="txt">
# <strong>내가 제일 힙해!</strong>
# <p>오늘 하루쯤 어디에서든지 제일 힙한 주인공이 되고 싶다면 매스노운 크롭 바시티 MA-1 점퍼를 걸치면 된다. 캐주얼한 바시티 재킷과 밀리터리 무드의 MA-1 항공 점퍼를 조합해 완성하여 색다른 무드가 포인트! 여기에 경쾌한 크롭 길이 디자인을 더해 S/S 시즌 활용도를 더욱 높여준다. 매스노운에서만 만날 수 있는 디자인으로 존재감을 뽐내보자! / 에디터 : 강진기</p>
# </div>
# <a href="https://store.musinsa.com/app/curating/views/23670" onclick="gtmClickList('큐레이팅', '');">상세보기</a>
# </div>
# </div>
# <div>
# <img alt="" class="img lazyload" data-original="//image.msscdn.net/data/curating/23669/23669_1_360.jpg" src="//image.msscdn.net/0.gif"/>
# <div class="cont">
# <div class="txt">
# <strong>이게 바로 바시티 감성!</strong>
# <p>클래식함과 캐주얼함을 고루 갖춘 그루브라임의 포틀랜드 후드 티. 앞면 중앙에 담긴 바시티 로고 디자인에서 클래식한 멋이 고스란히 느껴진다. 넉넉한 오버 핏에, 내구성 우수한 소재의 사용으로 단단한 핏까지 연출하는 것 또한 특징. 덕분에 자연스럽게 멋을 주고 싶을 때, 활용하기 좋겠다. / 에디터 : 최해리</p>
# </div>
# <a href="https://store.musinsa.com/app/curating/views/23669" onclick="gtmClickList('큐레이팅', '');">상세보기</a>
# </div>
# </div>
# <div>
# <img alt="" class="img lazyload" data-original="//image.msscdn.net/data/curating/23668/23668_1_360.jpg" src="//image.msscdn.net/0.gif"/>
# <div class="cont">
# <div class="txt">
# <strong>이젠 바람막이도 셋업으로 입어보자</strong>
# <p>노매뉴얼이 선보이는 윈드브레이커 셋업은 숏 팬츠와 매치해 입을 수 있다는 점에서 독특한 분위기를 만들어낸다. 여기에 더해 윈드브레이커 집업의 경우, 가슴 부분 간결한 로고 디테일과 스타일링에 용이한 밑단 스트링, 그리고 투웨이 지퍼까지 갖추고 있다. 쇼츠와 함께 입으면 셋업의 매력을 더 느낄 수 있다. / 에디터 : 김현중</p>
# </div>
# <a href="https://store.musinsa.com/app/curating/views/23668" onclick="gtmClickList('큐레이팅', '');">상세보기</a>
# </div>
# </div>
# <div>
# <img alt="" class="img lazyload" data-original="//image.msscdn.net/data/curating/23667/23667_1_360.jpg" src="//image.msscdn.net/0.gif"/>
# <div class="cont">
# <div class="txt">
# <strong>심플한 멋이 담긴 아이템</strong>
# <p>그라미치의 NN팬츠는 심플함을 가득 담고 있다. 그라미치의 아이코닉 디테일이라 할 수 있는 허벅지 안쪽 ‘가젯 크로치’ 패턴이 특징으로 슬림 스트레이트 핏을 자랑한다. 더불어 신축성이 뛰어난 소재를 통해 착용감과 내구성 모두 제 역할을 충실히 한다. 기능과 심플함 모두를 원한다면 그라미치의 아이템들을 주목해보자. / 에디터 : 김현중</p>
# </div>
# <a href="https://store.musinsa.com/app/curating/views/23667" onclick="gtmClickList('큐레이팅', '');">상세보기</a>
# </div>
# </div>
# </div>
# <div class="curating-area area2">
# <div>
# <img alt="" class="img lazyload" data-original="//image.msscdn.net/data/curating/23666/23666_1_360.jpg" src="//image.msscdn.net/0.gif"/>
# <div class="cont">
# <div class="txt">
# <strong>빈티지한 멋</strong>
# <p>시크한 무드가 물씬 느껴지는  엠엠지엘의 레더 블루종 재킷. 은은한 광택감과 불규칙한 링클, 크랙 디테일이 어우러져 고급스러우면서도 빈티지한 멋을 선사한다. 사이즈는 맨즈와 우먼즈, 두 가지로 구성되었으니 성별 관계없이 즐길 수 있겠다. / 에디터 : 최해리</p>
# </div>
# <a href="https://store.musinsa.com/app/curating/views/23666" onclick="gtmClickList('큐레이팅', '');">상세보기</a>
# </div>
# </div>
# <div>
# <img alt="" class="img lazyload" data-original="//image.msscdn.net/data/curating/23665/23665_1_360.jpg" src="//image.msscdn.net/0.gif"/>
# <div class="cont">
# <div class="txt">
# <strong>봄에는 블루 컬러를 들이자</strong>
# <p>파르티멘토의 데님 팬츠는 블루 컬러에 워싱 디테일을 잔잔하게 담아 생기가 느껴진다. 스트레이트 핏으로 베이식한 느낌을 줘 코디에 별다른 고민 없이 자주 손이 갈 아이템일 것. 여유 있게 떨어지는 밑단 라인은 자연스럽게 주름 효과를 주기도 하고 밑단을 접어 다양한 코디 연출을 하도록 돕는다. 적당한 두께감과 뛰어난 내구성으로 오랜 시간이 지나도 걱정 없이 꺼내 입을 수 있는 장점도 지녔다. / 에디터 : 임가현</p>
# </div>
# <a href="https://store.musinsa.com/app/curating/views/23665" onclick="gtmClickList('큐레이팅', '');">상세보기</a>
# </div>
# </div>
# <div>
# <img alt="" class="img lazyload" data-original="//image.msscdn.net/data/curating/23664/23664_1_360.jpg" src="//image.msscdn.net/0.gif"/>
# <div class="cont">
# <div class="txt">
# <strong>컬러 조합이 예술이야</strong>
# <p>너무 과하지 않으면서 적당히 꾸민 느낌을 주고 싶다면 밀로의 믹스드 크루넥 니트를 눈여겨보자. 다양한 컬러의 원사를 조합해 독특한 컬러 구성이 눈에 띄기 때문. 니트 하나만 입기 허전하다면 셔츠를 이너로 입거나 코트 등 차분한 무드의 아이템을 매치해도 좋다. 이때 서브 아이템을 무채색 컬러로 매치해 니트의 컬러감을 돋보이게 하는 방법을 잊지 말 것. / 에디터 : 임가현</p>
# </div>
# <a href="https://store.musinsa.com/app/curating/views/23664" onclick="gtmClickList('큐레이팅', '');">상세보기</a>
# </div>
# </div>
# <div>
# <img alt="" class="img lazyload" data-original="//image.msscdn.net/data/curating/23663/23663_1_360.jpg" src="//image.msscdn.net/0.gif"/>
# <div class="cont">
# <div class="txt">
# <strong>이 재킷, 은근 예쁜데?</strong>
# <p>야상은 어쩐지 후줄근해 보이고, 피시테일 재킷은 마음에 든다면 라퍼지스토어의 피시테일 숏 파카는 어떨까? 일반적인 피시테일 재킷의 길이와 달리 짧은 길이감이 봄에 어울리는 단출한 실루엣을 만들어준다. 허리의 스트링을 조이면 라인을 만들 수 있으며 키가 작은 이들도 부담 없이 입을 수 있다. 은근 멋 낸 듯 아닌 듯 입기 좋을 듯싶다! / 에디터 : 이보영</p>
# </div>
# <a href="https://store.musinsa.com/app/curating/views/23663" onclick="gtmClickList('큐레이팅', '');">상세보기</a>
# </div>
# </div>
# <div>
# <img alt="" class="img lazyload" data-original="//image.msscdn.net/data/curating/23662/23662_1_360.jpg" src="//image.msscdn.net/0.gif"/>
# <div class="cont">
# <div class="txt">
# <strong>나의 집콕 필수템!</strong>
# <p>집콕이 일상이 되어버렸다. 이럴 때 필요한 게 바로 스웨트 팬츠. 그리너리 크리드의 스웨트 팬츠는 조금 남다르다. 양쪽에 핀턱 주름을 넣어 스웨트 팬츠를 입었을 때도 슬랙스 같은 핏을 만들도록 디테일에 신경 썼다. 밑단은 발등에 툭 떨어지는 실루엣을 만들어주고, 허리엔 스트링을 더해 사이즈를 쉽게 조절할 수 있다. / 에디터 : 이보영</p>
# </div>
# <a href="https://store.musinsa.com/app/curating/views/23662" onclick="gtmClickList('큐레이팅', '');">상세보기</a>
# </div>
# </div>
# <div>
# <img alt="" class="img lazyload" data-original="//image.msscdn.net/data/curating/23661/23661_1_360.jpg" src="//image.msscdn.net/0.gif"/>
# <div class="cont">
# <div class="txt">
# <strong>세련된 스타일링의 기본</strong>
# <p>신발장 속에 하나쯤 구비해두면 좋은 무신사 스탠다드의 플레인 더비 슈즈. 라운드 토 셰이프의 클래식한 디자인으로 비즈니스 룩부터 깔끔한 캐주얼 룩까지 두루 소화할 수 있다. 천연 가죽 소재 본연의 고급스러운 광택이 스타일링의 세련된 포인트가 되어줄 것이다. / 에디터 : 최해리</p>
# </div>
# <a href="https://store.musinsa.com/app/curating/views/23661" onclick="gtmClickList('큐레이팅', '');">상세보기</a>
# </div>
# </div>
# </div>
# <div class="curating-area area3">
# <div>
# <img alt="" class="img lazyload" data-original="//image.msscdn.net/data/curating/23660/23660_1_360.jpg" src="//image.msscdn.net/0.gif"/>
# <div class="cont">
# <div class="txt">
# <strong>준비해 볼까 캠퍼스 룩!</strong>
# <p>이제 곧 시작될 신학기! 캠퍼스 룩을 고민하고 있다면 커버낫 칼리지 엠블럼 오버 핏 후드 티셔츠로 완벽한 코디를 준비해 보자. 앞면에 클래식한 아치 로고와 시즌 엠블럼을 커다랗게 더해 아이비리그 스타일로 완성했다. 깔끔한 데님 팬츠와 스니커즈 그리고 스포티한 백팩만 더하면 손쉽게 캠퍼스 룩 완성! / 에디터 : 강진기</p>
# </div>
# <a href="https://store.musinsa.com/app/curating/views/23660" onclick="gtmClickList('큐레이팅', '');">상세보기</a>
# </div>
# </div>
# <div>
# <img alt="" class="img lazyload" data-original="//image.msscdn.net/data/curating/23659/23659_1_360.jpg" src="//image.msscdn.net/0.gif"/>
# <div class="cont">
# <div class="txt">
# <strong>가젤이여 영원하여라</strong>
# <p>슈퍼스타, 스탠스미스 등 아디다스에는 세월이 지나도 변치 않는 멋으로 꾸준하게 사랑받는 스니커즈가 많다. 가젤 역시 빠질 수 없는 스테디셀러 아이템 중 하나. 축구화로 태어나 스트릿 스니커즈로 진화한 가젤을 1991년 모델과 동일한 소재와 컬러 그리고 조금 더 넓어진 비율로 선보인다. 매끈한 감촉과 고급스러운 무드의 누벅 소재의 어퍼가 가젤의 존재감을 더욱 부각한다. / 에디터 : 강진기</p>
# </div>
# <a href="https://store.musinsa.com/app/curating/views/23659" onclick="gtmClickList('큐레이팅', '');">상세보기</a>
# </div>
# </div>
# <div>
# <img alt="" class="img lazyload" data-original="//image.msscdn.net/data/curating/23658/23658_1_360.jpg" src="//image.msscdn.net/0.gif"/>
# <div class="cont">
# <div class="txt">
# <strong>봄을 위한 포인트</strong>
# <p>위트 있는 그래픽을 기반으로 한 컬렉션을 선보이는 원더 비지터. 이번 22 S/S 시즌 역시 톡톡 튀는 포인트 아이템들을 가득 들고 찾아왔다. 봄날에 만개한 꽃을 담아낸 듯한 니트 베스트, 특별한 날의 주인공으로 만들어 줄 그래픽 티셔츠 등 코디의 즐거움을 선사할 디자인이 가득하다. 매일 똑같은 데일리 룩에 싫증을 느꼈다면, 원더 비지터를 만나보길 바란다. / 에디터 : 최해리</p>
# </div>
# <a href="https://store.musinsa.com/app/curating/views/23658" onclick="gtmClickList('큐레이팅', '');">상세보기</a>
# </div>
# </div>
# <div>
# <img alt="" class="img lazyload" data-original="//image.msscdn.net/data/curating/23657/23657_1_360.jpg" src="//image.msscdn.net/0.gif"/>
# <div class="cont">
# <div class="txt">
# <strong>뭘 좋아할지 몰라서…</strong>
# <p>지플리시가 다~ 준비했다! 스타디움 재킷부터 레더 재킷, 항공 점퍼까지 모두의 취향을 만족시킬 알짜배기 아이템으로 말이다. 다양한 룩으로 활용하기 좋은 기본적인 디자인과 깔끔한 만듦새, 합리적인 가격대까지 빠지는 게 없는 베스트 아이템을 지금 바로 만나보자. / 에디터 : 이해인</p>
# </div>
# <a href="https://store.musinsa.com/app/curating/views/23657" onclick="gtmClickList('큐레이팅', '');">상세보기</a>
# </div>
# </div>
# <div>
# <img alt="" class="img lazyload" data-original="//image.msscdn.net/data/curating/23656/23656_1_360.jpg" src="//image.msscdn.net/0.gif"/>
# <div class="cont">
# <div class="txt">
# <strong>이렇게 가벼운 레더 재킷은 처음이야</strong>
# <p>겨울 추위가 조금씩 잦아들 때면 생각나는 레더 재킷. 가죽 하면 빼놓을 수 없는 도프제이슨이 웨어러블한 봄 신상 레더 재킷을 선보였다. 캐주얼한 윈드브레이커 디자인에 가벼운 비건 레더 소재를 사용해 활동성에 초점을 맞춘 것이 포인트! / 에디터 : 이해인</p>
# </div>
# <a href="https://store.musinsa.com/app/curating/views/23656" onclick="gtmClickList('큐레이팅', '');">상세보기</a>
# </div>
# </div>
# <div>
# <img alt="" class="img lazyload" data-original="//image.msscdn.net/data/curating/23655/23655_1_360.jpg" src="//image.msscdn.net/0.gif"/>
# <div class="cont">
# <div class="txt">
# <strong>귀여우니까 매일 입어줄게!</strong>
# <p>날이 따뜻해지니 귀여운 럭비 스웨트셔츠들이 여기저기서 등장하고 있다. 그중 마음을 빼앗긴 아이템은 바로 어반디타입 러닝 클럽 럭비 스웨트셔츠. 첫인상부터 귀여움 뿜뿜 매력이 느껴지는 아이템인데, 그 이유는 앞면의 선데이 러닝 클럽 타이포그래피와 캥거루 포켓 그리고 배색 포인트의 카라 디테일 덕분이다. 럭비 티셔츠는 역시 귀여워야 제맛이다. / 에디터 : 강진기</p>
# </div>
# <a href="https://store.musinsa.com/app/curating/views/23655" onclick="gtmClickList('큐레이팅', '');">상세보기</a>
# </div>
# </div>
# </div>
# </div>
# <!-- //큐레이팅 숍 목록 -->
# <!--큐레이팅 숍 텍스트-->
# <div class="right_container new-box-bottom">
# <div class="main_category_box">
# <h2 class="txt_tit_main">큐레이팅</h2><span class="txt_detail_link"><a href="https://store.musinsa.com/app/curating/lists" onclick="dataLayer.push({'layerCategory': '메인','layerAction':'큐레이팅_전체','layerLabel': '큐레이팅','event' : 'ga_event','nonInteraction' : false});">전체</a></span>
# </div>
# <p>무신사 큐레이팅숍 전문 패션 에디터가 직접 선정한 무신사 스토어에서 판매 중인 브랜드 상품을 스토리 그리고 이미지와 함께 소개합니다. </p>
# </div>
# <!--//큐레이팅 숍 텍스트-->
# <!-- 공지사항 -->
# <div class="right_container new-notice-area">
# <div class="main_category_box">
# <h2 class="txt_tit_main">공지사항</h2>
# <span class="txt_detail_link"><a href="https://store.musinsa.com/app/cs/notice_list" onclick="dataLayer.push({'layerCategory': '메인','layerAction':'공지사항_전체','layerLabel': '공지사항','event' : 'ga_event','nonInteraction' : false});">전체</a></span>
# </div>
# <div class="new-notice">
# <ul id="noticeSlide">
# <li><a href="https://store.musinsa.com/app/cs/notice_view/6654" onclick="gtmClickList('공지사항', '');"><span class="main_notice_txt ellipsis">아식스 일부 상품의 권장 소비자 가격이 변경됨을 안내드립니다.</span><span class="notice-date">22.01.27</span></a></li>
# <li><a href="https://store.musinsa.com/app/cs/notice_view/6534" onclick="gtmClickList('공지사항', '');"><span class="main_notice_txt ellipsis">무신사 스토어 스냅(SNAP) 서비스 이용 안내</span><span class="notice-date">22.01.20</span></a></li>
# <li><a href="https://store.musinsa.com/app/cs/notice_view/6402" onclick="gtmClickList('공지사항', '');"><span class="main_notice_txt ellipsis">택배사 파업으로 인한 배송 및 회수 지연 안내</span><span class="notice-date">21.12.31</span></a></li>
# <li><a href="https://store.musinsa.com/app/cs/notice_view/5943" onclick="gtmClickList('공지사항', '');"><span class="main_notice_txt ellipsis">친구 및 쪽지 서비스 종료 안내</span><span class="notice-date">21.09.17</span></a></li>
# <li><a href="https://store.musinsa.com/app/cs/notice_view/5879" onclick="gtmClickList('공지사항', '');"><span class="main_notice_txt ellipsis">무신사 스토어 대리구매 사기 유의 안내</span><span class="notice-date">21.09.09</span></a></li>
# </ul>
# </div>
# </div>
# <!-- //공지사항 -->
# <!-- 하단 콘텐츠 영역 -->
# <div id="footerCommonPc"></div>
# <meta content="NqB0BDAEWJTvAPCCxzrckJYnS7-xJILFU40FvSmh5S8" name="google-site-verification">
# <script async="true" src="//static.msscdn.net/skin/musinsa/js/jquery.url.packed.js" type="text/javascript"></script> <!--// 하단 콘텐츠 영역 -->
# </meta></div>
# <!--// 오른쪽 콘텐츠 영역 -->
# </div>
# <script>
# $(function() {
#     $("img.lazyload").lazyload();
# 	var $noticeSlide = $("#noticeSlide");
# 	var intervalFx = function(){
# 		$noticeSlide.animate({
# 			top : -21
# 		}, 500, "linear" , function(){
# 			$noticeSlide.find("li").eq(0).appendTo($noticeSlide);
# 			$noticeSlide.css("top" , 0);
# 		})
# 	};
#
# 	var slideInterval = setInterval(intervalFx,3000);
# 	$noticeSlide.hover(function(){
# 		clearInterval(slideInterval);
# 	},function(){
# 		slideInterval = setInterval(intervalFx,3000);
# 	});
# });
# </script>
# <!--// wrap -->
# </body>
# </html>

# %%
upper_category = [category for category in musinsa.findAll('strong', {'class':'title'})]
print(upper_category)
# Out:
# []
